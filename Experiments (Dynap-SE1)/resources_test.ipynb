# %% [markdown]
# ## Importing packages

# %%
import sys
sys.path.append('/home/class_NI2021/ctxctl_contrib_2023')
import samna
import samna.dynapse1 as dyn1
from dynapse1constants import *
import dynapse1utils as ut
import netgen as n
import params
import time
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pickle
import os

# %% [markdown]
# ## Looking for available devices

# %%
# Checking the list of unopened devices
devices = samna.device.get_unopened_devices()

if len(devices) == 0:
    raise Exception("no device detected!")

for i in range(len(devices)):
    print("["+str(i)+"]: ", devices[i], "serial_number", devices[i].serial_number)
# Out:
# [0]:  Bus 3 Device 4 Dynapse1DevKit serial_number 00000000
# [1]:  Bus 1 Device 10 Dynapse1DevKit serial_number 00000031
# [2]:  Bus 1 Device 15 Dynapse1DevKit serial_number 00000001

# %%
# Select one device from the list
model,no_gui = ut.open_dynapse1(gui=False, sender_port=17654, receiver_port=17523, select_device=True) # returns Dynapse1Model
# Out:
# ERROR: Address already in use, please re-run open_device()!
# [0]:  Bus 3 Device 4 Dynapse1DevKit serial_number 00000000
# [1]:  Bus 1 Device 10 Dynapse1DevKit serial_number 00000031
# [2]:  Bus 1 Device 15 Dynapse1DevKit serial_number 00000001

# %%
def build_inh_OR(n_inputs, debug):
    # silent all neurons: enforces some biases to ensure neurons are NOT firing
    paramGroup = params.gen_clean_param_group()
    for chip in range(4):
        for core in range(4):
            model.update_parameter_group(paramGroup, chip, core)

    api  = model.get_dynapse1_api()

    # ---- Parameters ----
    n_delay = 1

    # ---- Spike generator ----
    spike_generator_ids = range(1, n_inputs + 2)
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    id_ini = 1
    id_end = id_ini + n_delay
    delay_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 1
    nor_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 1
    not_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0

    # OP delayed
    net_gen.add_connection(spike_generators.neurons[0], delay_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses = total_synapses + 1
    for i in range(1, n_delay):
        net_gen.add_connection(delay_pop.neurons[i - 1], delay_pop.neurons[i], dyn1.Dynapse1SynType.AMPA)
        total_synapses = total_synapses + 1

    # OP to NOR
    net_gen.add_connection(spike_generators.neurons[0], nor_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses = total_synapses + 1

    # OP to NOT
    net_gen.add_connection(delay_pop.neurons[-1], not_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses = total_synapses + 1

    # Inputs to NOR
    for i in range(n_inputs):
        net_gen.add_connection(spike_generators.neurons[i + 1], nor_pop.neurons[0], dyn1.Dynapse1SynType.GABA_B)
        total_synapses = total_synapses + 1

    # NOR to NOT
    net_gen.add_connection(nor_pop.neurons[0], not_pop.neurons[0], dyn1.Dynapse1SynType.GABA_B)
    total_synapses = total_synapses + 1

    # make a dynapse1config using the network: that is convert the validated network to a Dynapse1 configuration
    new_config = net_gen.make_dynapse1_configuration()

    # apply the configuration
    model.apply_configuration(new_config)

    # Print resources
    neurons_count = id_end - 1
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = 3

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = n_inputs + 4

    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_inputs) + ": OK!")
    else:
        print("Test with " + str(n_inputs) + ": FAILED!")

# %%
for i in range(1, 51):
    build_inh_OR(i, 0)
# Out:
# Test with 1: OK!
# New configuration applied to DYNAP-SE1!
# Test with 2: OK!
# New configuration applied to DYNAP-SE1!
# Test with 3: OK!
# New configuration applied to DYNAP-SE1!
# Test with 4: OK!
# New configuration applied to DYNAP-SE1!
# Test with 5: OK!
# New configuration applied to DYNAP-SE1!
# Test with 6: OK!
# New configuration applied to DYNAP-SE1!
# Test with 7: OK!
# New configuration applied to DYNAP-SE1!
# Test with 8: OK!
# New configuration applied to DYNAP-SE1!
# Test with 9: OK!New configuration applied to DYNAP-SE1!
#
# Test with 10: OK!
# New configuration applied to DYNAP-SE1!
# Test with 11: OK!
# New configuration applied to DYNAP-SE1!
# Test with 12: OK!
# New configuration applied to DYNAP-SE1!
# Test with 13: OK!
# New configuration applied to DYNAP-SE1!
# Test with 14: OK!
# New configuration applied to DYNAP-SE1!
# Test with 15: OK!
# New configuration applied to DYNAP-SE1!
# Test with 16: OK!
# New configuration applied to DYNAP-SE1!
# Test with 17: OK!
# New configuration applied to DYNAP-SE1!
# Test with 18: OK!
# New configuration applied to DYNAP-SE1!
# Test with 19: OK!
# New configuration applied to DYNAP-SE1!
# Test with 20: OK!
# New configuration applied to DYNAP-SE1!
# Test with 21: OK!
# New configuration applied to DYNAP-SE1!
# Test with 22: OK!
# New configuration applied to DYNAP-SE1!
# Test with 23: OK!
# New configuration applied to DYNAP-SE1!
# Test with 24: OK!
# New configuration applied to DYNAP-SE1!
# Test with 25: OK!New configuration applied to DYNAP-SE1!
#
# Test with 26: OK!
# New configuration applied to DYNAP-SE1!
# Test with 27: OK!
# New configuration applied to DYNAP-SE1!
# Test with 28: OK!
# New configuration applied to DYNAP-SE1!
# Test with 29: OK!
# New configuration applied to DYNAP-SE1!
# Test with 30: OK!
# New configuration applied to DYNAP-SE1!
# Test with 31: OK!
# New configuration applied to DYNAP-SE1!
# Test with 32: OK!
# New configuration applied to DYNAP-SE1!
# Test with 33: OK!
# New configuration applied to DYNAP-SE1!
# Test with 34: OK!
# New configuration applied to DYNAP-SE1!
# Test with 35: OK!
# New configuration applied to DYNAP-SE1!
# Test with 36: OK!
# New configuration applied to DYNAP-SE1!
# Test with 37: OK!
# New configuration applied to DYNAP-SE1!
# Test with 38: OK!
# New configuration applied to DYNAP-SE1!
# Test with 39: OK!
# New configuration applied to DYNAP-SE1!
# Test with 40: OK!
# New configuration applied to DYNAP-SE1!
# Test with 41: OK!New configuration applied to DYNAP-SE1!
#
# Test with 42: OK!
# New configuration applied to DYNAP-SE1!
# Test with 43: OK!New configuration applied to DYNAP-SE1!
#
# Test with 44: OK!
# New configuration applied to DYNAP-SE1!
# Test with 45: OK!New configuration applied to DYNAP-SE1!
#
# Test with 46: OK!
# New configuration applied to DYNAP-SE1!
# Test with 47: OK!New configuration applied to DYNAP-SE1!
#
# Test with 48: OK!
# New configuration applied to DYNAP-SE1!
# Test with 49: OK!New configuration applied to DYNAP-SE1!
#
# Test with 50: OK!
# New configuration applied to DYNAP-SE1!

# %%
def build_alt_OR(n_inputs, debug):
    # silent all neurons: enforces some biases to ensure neurons are NOT firing
    paramGroup = params.gen_clean_param_group()
    for chip in range(4):
        for core in range(4):
            model.update_parameter_group(paramGroup, chip, core)

    api  = model.get_dynapse1_api()

    # ---- Parameters ----
    n_delay = 1

    # ---- Spike generator ----
    spike_generator_ids = range(1, n_inputs + 1)
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    id_ini = 1
    id_end = id_ini + n_inputs
    or_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 1
    join_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0

    # OP_i to neuron i
    for i in range(n_inputs):
        net_gen.add_connection(spike_generators.neurons[i], or_pop.neurons[i], dyn1.Dynapse1SynType.AMPA)
        total_synapses = total_synapses + 1

        for j in range(i):
            net_gen.add_connection(spike_generators.neurons[j], or_pop.neurons[i], dyn1.Dynapse1SynType.GABA_B)
            total_synapses = total_synapses + 1

        # Joining from or_pop
        net_gen.add_connection(or_pop.neurons[i], join_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
        total_synapses = total_synapses + 1

    # make a dynapse1config using the network: that is convert the validated network to a Dynapse1 configuration
    new_config = net_gen.make_dynapse1_configuration()

    # apply the configuration
    model.apply_configuration(new_config)

    # Print resources
    neurons_count = id_end - 1
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = n_inputs + 1

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = 1 / 2 * n_inputs ** 2 + 3 / 2 * n_inputs

    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_inputs) + ": OK!")
    else:
        print("Test with " + str(n_inputs) + ": FAILED!")

# %%
for i in range(1, 51):
    build_alt_OR(i, 0)
# Out:
# Test with 1: OK!New configuration applied to DYNAP-SE1!
#
# Test with 2: OK!
# New configuration applied to DYNAP-SE1!
# Test with 3: OK!
# New configuration applied to DYNAP-SE1!
# Test with 4: OK!
# New configuration applied to DYNAP-SE1!
# Test with 5: OK!
# New configuration applied to DYNAP-SE1!
# Test with 6: OK!
# New configuration applied to DYNAP-SE1!
# Test with 7: OK!
# New configuration applied to DYNAP-SE1!
# Test with 8: OK!
# New configuration applied to DYNAP-SE1!
# Test with 9: OK!
# New configuration applied to DYNAP-SE1!
# Test with 10: OK!
# New configuration applied to DYNAP-SE1!
# Test with 11: OK!
# New configuration applied to DYNAP-SE1!
# Test with 12: OK!
# New configuration applied to DYNAP-SE1!
# Test with 13: OK!
# New configuration applied to DYNAP-SE1!
# Test with 14: OK!
# New configuration applied to DYNAP-SE1!
# Test with 15: OK!
# New configuration applied to DYNAP-SE1!
# Test with 16: OK!New configuration applied to DYNAP-SE1!
#
# Test with 17: OK!
# New configuration applied to DYNAP-SE1!
# Test with 18: OK!
# New configuration applied to DYNAP-SE1!
# Test with 19: OK!
# New configuration applied to DYNAP-SE1!
# Test with 20: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 21: OK!
# Test with 22: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 23: OK!
# Test with 24: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 25: OK!
# New configuration applied to DYNAP-SE1!
# Test with 26: OK!
# Test with 27: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 28: OK!
# New configuration applied to DYNAP-SE1!
# Test with 29: OK!
# Test with 30: OK!New configuration applied to DYNAP-SE1!
#
# Test with 31: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 32: OK!
# New configuration applied to DYNAP-SE1!
# Test with 33: OK!
# Test with 34: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 35: OK!
# New configuration applied to DYNAP-SE1!
# Test with 36: OK!
# New configuration applied to DYNAP-SE1!
# Test with 37: OK!
# New configuration applied to DYNAP-SE1!
# Test with 38: OK!
# New configuration applied to DYNAP-SE1!
# Test with 39: OK!
# New configuration applied to DYNAP-SE1!
# Test with 40: OK!
# New configuration applied to DYNAP-SE1!
# Test with 41: OK!
# New configuration applied to DYNAP-SE1!
# Test with 42: OK!
# New configuration applied to DYNAP-SE1!
# Test with 43: OK!
# New configuration applied to DYNAP-SE1!
# Test with 44: OK!
# New configuration applied to DYNAP-SE1!
# Test with 45: OK!
# New configuration applied to DYNAP-SE1!
# Test with 46: OK!
# New configuration applied to DYNAP-SE1!
# Test with 47: OK!
# New configuration applied to DYNAP-SE1!
# Test with 48: OK!
# New configuration applied to DYNAP-SE1!
# Test with 49: OK!
# New configuration applied to DYNAP-SE1!
# Test with 50: OK!

# %%
def build_inh_AND(n_inputs, debug):
    # silent all neurons: enforces some biases to ensure neurons are NOT firing
    paramGroup = params.gen_clean_param_group()
    for chip in range(4):
        for core in range(4):
            model.update_parameter_group(paramGroup, chip, core)

    api  = model.get_dynapse1_api()

    # ---- Parameters ----
    n_delay = 1

    # ---- Spike generator ----
    spike_generator_ids = range(1, n_inputs + 2)
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    id_ini = 1
    id_end = id_ini + n_delay
    delay_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += n_inputs
    not_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 1
    nor_pop = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0

    # OP delayed
    net_gen.add_connection(spike_generators.neurons[0], delay_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses = total_synapses + 1
    for i in range(1, n_delay):
        net_gen.add_connection(delay_pop.neurons[i - 1], delay_pop.neurons[i], dyn1.Dynapse1SynType.AMPA)
        total_synapses = total_synapses + 1

    # OP to NOT
    for i in range(n_inputs):
        net_gen.add_connection(spike_generators.neurons[0], not_pop.neurons[i], dyn1.Dynapse1SynType.AMPA)
        total_synapses = total_synapses + 1

    # OP to NOR
    net_gen.add_connection(delay_pop.neurons[-1], nor_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses = total_synapses + 1

    # Inputs to NOT
    for i in range(n_inputs):
        net_gen.add_connection(spike_generators.neurons[i + 1], not_pop.neurons[i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses = total_synapses + 1

    # NOT to NOR
    for i in range(n_inputs):
        net_gen.add_connection(not_pop.neurons[i], nor_pop.neurons[0], dyn1.Dynapse1SynType.GABA_B)
        total_synapses = total_synapses + 1

    # make a dynapse1config using the network: that is convert the validated network to a Dynapse1 configuration
    new_config = net_gen.make_dynapse1_configuration()

    # apply the configuration
    model.apply_configuration(new_config)

    # Print resources
    neurons_count = id_end - 1
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = n_inputs + 2

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = 3 * n_inputs + 2

    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_inputs) + ": OK!")
    else:
        print("Test with " + str(n_inputs) + ": FAILED!")

# %%
for i in range(1, 51):
    build_inh_AND(i, 0)
# Out:
# Test with 1: OK!
# New configuration applied to DYNAP-SE1!
# Test with 2: OK!
# New configuration applied to DYNAP-SE1!
# Test with 3: OK!
# New configuration applied to DYNAP-SE1!
# Test with 4: OK!
# New configuration applied to DYNAP-SE1!
# Test with 5: OK!New configuration applied to DYNAP-SE1!
#
# Test with 6: OK!
# New configuration applied to DYNAP-SE1!
# Test with 7: OK!New configuration applied to DYNAP-SE1!
#
# Test with 8: OK!
# New configuration applied to DYNAP-SE1!
# Test with 9: OK!New configuration applied to DYNAP-SE1!
#
# Test with 10: OK!
# New configuration applied to DYNAP-SE1!
# Test with 11: OK!
# New configuration applied to DYNAP-SE1!
# Test with 12: OK!
# New configuration applied to DYNAP-SE1!
# Test with 13: OK!
# New configuration applied to DYNAP-SE1!
# Test with 14: OK!
# New configuration applied to DYNAP-SE1!
# Test with 15: OK!
# New configuration applied to DYNAP-SE1!
# Test with 16: OK!
# New configuration applied to DYNAP-SE1!
# Test with 17: OK!
# New configuration applied to DYNAP-SE1!
# Test with 18: OK!
# New configuration applied to DYNAP-SE1!
# Test with 19: OK!
# New configuration applied to DYNAP-SE1!
# Test with 20: OK!
# New configuration applied to DYNAP-SE1!
# Test with 21: OK!
# New configuration applied to DYNAP-SE1!
# Test with 22: OK!
# New configuration applied to DYNAP-SE1!
# Test with 23: OK!
# New configuration applied to DYNAP-SE1!
# Test with 24: OK!
# New configuration applied to DYNAP-SE1!
# Test with 25: OK!
# New configuration applied to DYNAP-SE1!
# Test with 26: OK!
# New configuration applied to DYNAP-SE1!
# Test with 27: OK!
# New configuration applied to DYNAP-SE1!
# Test with 28: OK!
# New configuration applied to DYNAP-SE1!
# Test with 29: OK!
# New configuration applied to DYNAP-SE1!
# Test with 30: OK!
# New configuration applied to DYNAP-SE1!
# Test with 31: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 32: OK!
# Test with 33: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 34: OK!
# Test with 35: OK!
# New configuration applied to DYNAP-SE1!
# Test with 36: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 37: OK!
# Test with 38: OK!
# New configuration applied to DYNAP-SE1!
# Test with 39: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 40: OK!
# Test with 41: OK!
# New configuration applied to DYNAP-SE1!
# Test with 42: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 43: OK!
# New configuration applied to DYNAP-SE1!
# Test with 44: OK!
# New configuration applied to DYNAP-SE1!
# Test with 45: OK!
# New configuration applied to DYNAP-SE1!
# Test with 46: OK!
# New configuration applied to DYNAP-SE1!
# Test with 47: OK!
# New configuration applied to DYNAP-SE1!
# Test with 48: OK!
# Test with 49: OK!
# New configuration applied to DYNAP-SE1!
# New configuration applied to DYNAP-SE1!
# Test with 50: OK!

# %%
def build_adder(n_bits, debug):
    # silent all neurons: enforces some biases to ensure neurons are NOT firing
    paramGroup = params.gen_clean_param_group()
    for chip in range(4):
        for core in range(4):
            model.update_parameter_group(paramGroup, chip, core)

    api  = model.get_dynapse1_api()

    # ---- Spike generator ----
    id_ini = 1
    id_end = id_ini + n_bits * 2 + 1
    spike_generator_ids = np.array(range(id_ini, id_end))
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    core_id = 1

    id_ini = id_end
    if n_bits > 1:
        id_end = id_ini + 5 * (n_bits - 1)
    else:
        id_end = id_ini + 1
    op_delay_pop = n.NeuronGroup(0, core_id, range(id_ini, id_end), False)

    a_delay_pop = []
    for i in range(n_bits - 1):
        id_ini = id_end
        id_end += 2 + 5 * i
        a_delay_pop.append(n.NeuronGroup(0, core_id, range(id_ini, id_end), False))

    b_delay_pop = []
    for i in range(n_bits - 1):
        id_ini = id_end
        id_end += 2 + 5 * i
        b_delay_pop.append(n.NeuronGroup(0, core_id, range(id_ini, id_end), False))

    id_ini = id_end
    id_end += 6
    ha_pop = n.NeuronGroup(0, core_id, range(id_ini, id_end), False)

    if n_bits > 1:
        id_ini = id_end
        id_end += 18 * (n_bits - 1)
        fa_pop = n.NeuronGroup(0, core_id, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0

    # OP chain
    net_gen.add_connection(spike_generators.neurons[0], op_delay_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    total_synapses += 1
    for i in range(1, len(op_delay_pop.neurons)):
        net_gen.add_connection(op_delay_pop.neurons[i - 1], op_delay_pop.neurons[i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

    # OP to NOT
    net_gen.add_connection(spike_generators.neurons[0], ha_pop.neurons[0], dyn1.Dynapse1SynType.AMPA)
    net_gen.add_connection(spike_generators.neurons[0], ha_pop.neurons[1], dyn1.Dynapse1SynType.AMPA)
    total_synapses += 2
    for i in range(n_bits - 1):
        net_gen.add_connection(op_delay_pop.neurons[1 + 5 * i], fa_pop.neurons[18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(op_delay_pop.neurons[1 + 5 * i], fa_pop.neurons[18 * i + 1], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2
        
    # A and B chains -> A0 y B0 are not delayed!
    for i in range(1, n_bits):
        net_gen.add_connection(spike_generators.neurons[1 + i], a_delay_pop[i-1].neurons[0], dyn1.Dynapse1SynType.AMPA)  # A
        net_gen.add_connection(spike_generators.neurons[1 + i + n_bits], b_delay_pop[i-1].neurons[0], dyn1.Dynapse1SynType.AMPA)  # B
        total_synapses += 2

    for i in range(n_bits - 1):
        for j in range(1, len(a_delay_pop[i].neurons)):
            net_gen.add_connection(a_delay_pop[i].neurons[j - 1], a_delay_pop[i].neurons[j], dyn1.Dynapse1SynType.AMPA)
            total_synapses += 1
        for j in range(1, len(b_delay_pop[i].neurons)):
            net_gen.add_connection(b_delay_pop[i].neurons[j - 1], b_delay_pop[i].neurons[j], dyn1.Dynapse1SynType.AMPA)
            total_synapses += 1

    # Input to NOT
    net_gen.add_connection(spike_generators.neurons[1], ha_pop.neurons[0], dyn1.Dynapse1SynType.GABA_B)  # A
    net_gen.add_connection(spike_generators.neurons[1 + n_bits], ha_pop.neurons[1], dyn1.Dynapse1SynType.GABA_B)  # B
    total_synapses += 2
    for i in range(n_bits - 1):
        net_gen.add_connection(a_delay_pop[i].neurons[len(a_delay_pop[i].neurons) - 1], fa_pop.neurons[18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(b_delay_pop[i].neurons[len(b_delay_pop[i].neurons) - 1], fa_pop.neurons[18 * i + 1], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2

    # --------- HA internal structure ----------
    # 2
    net_gen.add_connection(op_delay_pop.neurons[0], ha_pop.neurons[2], dyn1.Dynapse1SynType.AMPA)
    net_gen.add_connection(ha_pop.neurons[0], ha_pop.neurons[2], dyn1.Dynapse1SynType.GABA_B)
    net_gen.add_connection(ha_pop.neurons[1], ha_pop.neurons[2], dyn1.Dynapse1SynType.GABA_B)
    total_synapses += 3

    # 3
    net_gen.add_connection(ha_pop.neurons[0], ha_pop.neurons[3], dyn1.Dynapse1SynType.AMPA)
    net_gen.add_connection(ha_pop.neurons[1], ha_pop.neurons[3], dyn1.Dynapse1SynType.GABA_B)
    total_synapses += 2

    # 4
    net_gen.add_connection(ha_pop.neurons[0], ha_pop.neurons[4], dyn1.Dynapse1SynType.GABA_B)
    net_gen.add_connection(ha_pop.neurons[1], ha_pop.neurons[4], dyn1.Dynapse1SynType.AMPA)
    total_synapses += 2

    # 5
    net_gen.add_connection(ha_pop.neurons[3], ha_pop.neurons[5], dyn1.Dynapse1SynType.AMPA)
    net_gen.add_connection(ha_pop.neurons[4], ha_pop.neurons[5], dyn1.Dynapse1SynType.AMPA)
    total_synapses += 2

    # Connecting to the next adder
    if n_bits > 1:
        net_gen.add_connection(ha_pop.neurons[2], fa_pop.neurons[2], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

    # --------- FA internal structure ----------
    for i in range(n_bits - 1):
        # 3
        net_gen.add_connection(op_delay_pop.neurons[2 + 5 * i], fa_pop.neurons[3 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[0 + 18 * i], fa_pop.neurons[3 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(fa_pop.neurons[1 + 18 * i], fa_pop.neurons[3 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 3

        # 4
        net_gen.add_connection(fa_pop.neurons[0 + 18 * i], fa_pop.neurons[4 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[1 + 18 * i], fa_pop.neurons[4 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2

        # 5
        net_gen.add_connection(fa_pop.neurons[0 + 18 * i], fa_pop.neurons[5 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(fa_pop.neurons[1 + 18 * i], fa_pop.neurons[5 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2

        # 6
        net_gen.add_connection(fa_pop.neurons[2 + 18 * i], fa_pop.neurons[6 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

        # 7
        net_gen.add_connection(fa_pop.neurons[3 + 18 * i], fa_pop.neurons[7 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

        # 8
        net_gen.add_connection(op_delay_pop.neurons[3 + 5 * i], fa_pop.neurons[8 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[4 + 18 * i], fa_pop.neurons[8 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(fa_pop.neurons[5 + 18 * i], fa_pop.neurons[8 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 3

        # 9
        net_gen.add_connection(fa_pop.neurons[4 + 18 * i], fa_pop.neurons[9 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[5 + 18 * i], fa_pop.neurons[9 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2

        # 10
        net_gen.add_connection(fa_pop.neurons[6 + 18 * i], fa_pop.neurons[10 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

        # 11
        net_gen.add_connection(op_delay_pop.neurons[3 + 5 * i], fa_pop.neurons[11 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[6 + 18 * i], fa_pop.neurons[11 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2

        # 12
        net_gen.add_connection(fa_pop.neurons[7 + 18 * i], fa_pop.neurons[12 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 1

        # 13
        net_gen.add_connection(op_delay_pop.neurons[4 + 5 * i], fa_pop.neurons[13 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[8 + 18 * i], fa_pop.neurons[13 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(fa_pop.neurons[11 + 18 * i], fa_pop.neurons[13 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 3

        # 14
        net_gen.add_connection(fa_pop.neurons[9 + 18 * i], fa_pop.neurons[14 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[10 + 18 * i], fa_pop.neurons[14 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2

        # 15
        net_gen.add_connection(fa_pop.neurons[9 + 18 * i], fa_pop.neurons[15 + 18 * i], dyn1.Dynapse1SynType.GABA_B)
        net_gen.add_connection(fa_pop.neurons[10 + 18 * i], fa_pop.neurons[15 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2

        # 16
        net_gen.add_connection(fa_pop.neurons[12 + 18 * i], fa_pop.neurons[16 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[13 + 18 * i], fa_pop.neurons[16 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2
        # Connecting to the next adder
        if i != (n_bits - 2):
            net_gen.add_connection(fa_pop.neurons[16 + 18 * i], fa_pop.neurons[2 + 18 * (i + 1)], dyn1.Dynapse1SynType.AMPA)
            total_synapses += 1

        # 17
        net_gen.add_connection(fa_pop.neurons[14 + 18 * i], fa_pop.neurons[17 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(fa_pop.neurons[15 + 18 * i], fa_pop.neurons[17 + 18 * i], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2

    # make a dynapse1config using the network: that is convert the validated network to a Dynapse1 configuration
    new_config = net_gen.make_dynapse1_configuration()

    # apply the configuration
    model.apply_configuration(new_config)

    # Print resources
    neurons_count = id_end - 1 - (n_bits * 2 + 1)
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = 5 * (n_bits - 2) ** 2 + 5 * (n_bits - 2) + 27 * (n_bits - 1) + 6

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = 5 * (n_bits - 2) ** 2 + 5 * (n_bits - 2) + 43 * (n_bits - 1) + 13

    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_bits) + ": OK!")
    else:
        print("Test with " + str(n_bits) + ": FAILED!")

# %%
for i in range(2, 7):
    build_adder(i, 1)
# Out:
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n6: [('C0c0s1', 'AMPA')]
# C0c1n7: [('C0c1n6', 'AMPA')]
# C0c1n8: [('C0c1n7', 'AMPA')]
# C0c1n9: [('C0c1n8', 'AMPA')]
# C0c1n10: [('C0c1n9', 'AMPA')]
# C0c1n15: [('C0c0s1', 'AMPA'), ('C0c0s2', 'GABA_B')]
# C0c1n16: [('C0c0s1', 'AMPA'), ('C0c0s4', 'GABA_B')]
# C0c1n21: [('C0c1n7', 'AMPA'), ('C0c1n12', 'GABA_B')]
# C0c1n22: [('C0c1n7', 'AMPA'), ('C0c1n14', 'GABA_B')]
# C0c1n11: [('C0c0s3', 'AMPA')]
# C0c1n13: [('C0c0s5', 'AMPA')]
# C0c1n12: [('C0c1n11', 'AMPA')]
# C0c1n14: [('C0c1n13', 'AMPA')]
# C0c1n17: [('C0c1n6', 'AMPA'), ('C0c1n15', 'GABA_B'), ('C0c1n16', 'GABA_B')]
# C0c1n18: [('C0c1n15', 'AMPA'), ('C0c1n16', 'GABA_B')]
# C0c1n19: [('C0c1n15', 'GABA_B'), ('C0c1n16', 'AMPA')]
# C0c1n20: [('C0c1n18', 'AMPA'), ('C0c1n19', 'AMPA')]
# C0c1n23: [('C0c1n17', 'AMPA')]
# C0c1n24: [('C0c1n8', 'AMPA'), ('C0c1n21', 'GABA_B'), ('C0c1n22', 'GABA_B')]
# C0c1n25: [('C0c1n21', 'AMPA'), ('C0c1n22', 'GABA_B')]
# C0c1n26: [('C0c1n21', 'GABA_B'), ('C0c1n22', 'AMPA')]
# C0c1n27: [('C0c1n23', 'AMPA')]
# C0c1n28: [('C0c1n24', 'AMPA')]
# C0c1n29: [('C0c1n9', 'AMPA'), ('C0c1n25', 'GABA_B'), ('C0c1n26', 'GABA_B')]
# C0c1n30: [('C0c1n25', 'AMPA'), ('C0c1n26', 'AMPA')]
# C0c1n31: [('C0c1n27', 'AMPA')]
# C0c1n32: [('C0c1n9', 'AMPA'), ('C0c1n27', 'GABA_B')]
# C0c1n33: [('C0c1n28', 'AMPA')]
# C0c1n34: [('C0c1n10', 'AMPA'), ('C0c1n29', 'GABA_B'), ('C0c1n32', 'GABA_B')]
# C0c1n35: [('C0c1n30', 'AMPA'), ('C0c1n31', 'GABA_B')]
# C0c1n36: [('C0c1n30', 'GABA_B'), ('C0c1n31', 'AMPA')]
# C0c1n37: [('C0c1n33', 'AMPA'), ('C0c1n34', 'AMPA')]
# C0c1n38: [('C0c1n35', 'AMPA'), ('C0c1n36', 'AMPA')]
# New configuration applied to DYNAP-SE1!
#
# Number of neurons (using count): 33
# Number of neurons (using net_gen.network): 33
# Number of neurons (using the formula): 33
# Number of synapses (using count): 56
# Number of synapses (using net_gen.network): 56
# Number of synapses (using the formula): 56
# Test with 2: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n8: [('C0c0s1', 'AMPA')]
# C0c1n9: [('C0c1n8', 'AMPA')]
# C0c1n10: [('C0c1n9', 'AMPA')]
# C0c1n11: [('C0c1n10', 'AMPA')]
# C0c1n12: [('C0c1n11', 'AMPA')]
# C0c1n13: [('C0c1n12', 'AMPA')]
# C0c1n14: [('C0c1n13', 'AMPA')]
# C0c1n15: [('C0c1n14', 'AMPA')]
# C0c1n16: [('C0c1n15', 'AMPA')]
# C0c1n17: [('C0c1n16', 'AMPA')]
# C0c1n36: [('C0c0s1', 'AMPA'), ('C0c0s2', 'GABA_B')]
# C0c1n37: [('C0c0s1', 'AMPA'), ('C0c0s5', 'GABA_B')]
# C0c1n42: [('C0c1n9', 'AMPA'), ('C0c1n19', 'GABA_B')]
# C0c1n43: [('C0c1n9', 'AMPA'), ('C0c1n28', 'GABA_B')]
# C0c1n60: [('C0c1n14', 'AMPA'), ('C0c1n26', 'GABA_B')]
# C0c1n61: [('C0c1n14', 'AMPA'), ('C0c1n35', 'GABA_B')]
# C0c1n18: [('C0c0s3', 'AMPA')]
# C0c1n27: [('C0c0s6', 'AMPA')]
# C0c1n20: [('C0c0s4', 'AMPA')]
# C0c1n29: [('C0c0s7', 'AMPA')]
# C0c1n19: [('C0c1n18', 'AMPA')]
# C0c1n28: [('C0c1n27', 'AMPA')]
# C0c1n21: [('C0c1n20', 'AMPA')]
# C0c1n22: [('C0c1n21', 'AMPA')]
# C0c1n23: [('C0c1n22', 'AMPA')]
# C0c1n24: [('C0c1n23', 'AMPA')]
# C0c1n25: [('C0c1n24', 'AMPA')]
# C0c1n26: [('C0c1n25', 'AMPA')]
# C0c1n30: [('C0c1n29', 'AMPA')]
# C0c1n31: [('C0c1n30', 'AMPA')]
# C0c1n32: [('C0c1n31', 'AMPA')]
# C0c1n33: [('C0c1n32', 'AMPA')]
# C0c1n34: [('C0c1n33', 'AMPA')]
# C0c1n35: [('C0c1n34', 'AMPA')]
# C0c1n38: [('C0c1n8', 'AMPA'), ('C0c1n36', 'GABA_B'), ('C0c1n37', 'GABA_B')]
# C0c1n39: [('C0c1n36', 'AMPA'), ('C0c1n37', 'GABA_B')]
# C0c1n40: [('C0c1n36', 'GABA_B'), ('C0c1n37', 'AMPA')]
# C0c1n41: [('C0c1n39', 'AMPA'), ('C0c1n40', 'AMPA')]
# C0c1n44: [('C0c1n38', 'AMPA')]
# C0c1n45: [('C0c1n10', 'AMPA'), ('C0c1n42', 'GABA_B'), ('C0c1n43', 'GABA_B')]
# C0c1n46: [('C0c1n42', 'AMPA'), ('C0c1n43', 'GABA_B')]
# C0c1n47: [('C0c1n42', 'GABA_B'), ('C0c1n43', 'AMPA')]
# C0c1n48: [('C0c1n44', 'AMPA')]
# C0c1n49: [('C0c1n45', 'AMPA')]
# C0c1n50: [('C0c1n11', 'AMPA'), ('C0c1n46', 'GABA_B'), ('C0c1n47', 'GABA_B')]
# C0c1n51: [('C0c1n46', 'AMPA'), ('C0c1n47', 'AMPA')]
# C0c1n52: [('C0c1n48', 'AMPA')]
# C0c1n53: [('C0c1n11', 'AMPA'), ('C0c1n48', 'GABA_B')]
# C0c1n54: [('C0c1n49', 'AMPA')]
# C0c1n55: [('C0c1n12', 'AMPA'), ('C0c1n50', 'GABA_B'), ('C0c1n53', 'GABA_B')]
# C0c1n56: [('C0c1n51', 'AMPA'), ('C0c1n52', 'GABA_B')]
# C0c1n57: [('C0c1n51', 'GABA_B'), ('C0c1n52', 'AMPA')]
# C0c1n58: [('C0c1n54', 'AMPA'), ('C0c1n55', 'AMPA')]
# C0c1n62: [('C0c1n58', 'AMPA')]
# C0c1n59: [('C0c1n56', 'AMPA'), ('C0c1n57', 'AMPA')]
# C0c1n63: [('C0c1n15', 'AMPA'), ('C0c1n60', 'GABA_B'), ('C0c1n61', 'GABA_B')]
# C0c1n64: [('C0c1n60', 'AMPA'), ('C0c1n61', 'GABA_B')]
# C0c1n65: [('C0c1n60', 'GABA_B'), ('C0c1n61', 'AMPA')]
# C0c1n66: [('C0c1n62', 'AMPA')]
# C0c1n67: [('C0c1n63', 'AMPA')]
# C0c1n68: [('C0c1n16', 'AMPA'), ('C0c1n64', 'GABA_B'), ('C0c1n65', 'GABA_B')]
# C0c1n69: [('C0c1n64', 'AMPA'), ('C0c1n65', 'AMPA')]
# C0c1n70: [('C0c1n66', 'AMPA')]
# C0c1n71: [('C0c1n16', 'AMPA'), ('C0c1n66', 'GABA_B')]
# C0c1n72: [('C0c1n67', 'AMPA')]
# C0c1n73: [('C0c1n17', 'AMPA'), ('C0c1n68', 'GABA_B'), ('C0c1n71', 'GABA_B')]
# C0c1n74: [('C0c1n69', 'AMPA'), ('C0c1n70', 'GABA_B')]
# C0c1n75: [('C0c1n69', 'GABA_B'), ('C0c1n70', 'AMPA')]
# C0c1n76: [('C0c1n72', 'AMPA'), ('C0c1n73', 'AMPA')]
# C0c1n77: [('C0c1n74', 'AMPA'), ('C0c1n75', 'AMPA')]
#
# Number of neurons (using count): 70
# Number of neurons (using net_gen.network): 70
# Number of neurons (using the formula): 70
# Number of synapses (using count): 109
# Number of synapses (using net_gen.network): 109
# Number of synapses (using the formula): 109
# Test with 3: OK!
# New configuration applied to DYNAP-SE1!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1
# C0c1n106: [('C0c1n100', 'GABA_B'), ('C0c1n101', 'AMPA')]
# C0c1n107: [('C0c1n103', 'AMPA'), ('C0c1n104', 'AMPA')]
# C0c1n111: [('C0c1n107', 'AMPA')]
# C0c1n108: [('C0c1n105', 'AMPA'), ('C0c1n106', 'AMPA')]
# C0c1n112: [('C0c1n22', 'AMPA'), ('C0c1n109', 'GABA_B'), ('C0c1n110', 'GABA_B')]
# C0c1n113: [('C0c1n109', 'AMPA'), ('C0c1n110', 'GABA_B')]
# C0c1n114: [('C0c1n109', 'GABA_B'), ('C0c1n110', 'AMPA')]
# C0c1n115: [('C0c1n111', 'AMPA')]
# C0c1n116: [('C0c1n112', 'AMPA')]
# C0c1n117: [('C0c1n23', 'AMPA'), ('C0c1n113', 'GABA_B'), ('C0c1n114', 'GABA_B')]
# C0c1n118: [('C0c1n113', 'AMPA'), ('C0c1n114', 'AMPA')]
# C0c1n119: [('C0c1n115', 'AMPA')]
# C0c1n120: [('C0c1n23', 'AMPA'), ('C0c1n115', 'GABA_B')]
# C0c1n121: [('C0c1n116', 'AMPA')]
# C0c1n122: [('C0c1n24', 'AMPA'), ('C0c1n117', 'GABA_B'), ('C0c1n120', 'GABA_B')]
# C0c1n123: [('C0c1n118', 'AMPA'), ('C0c1n119', 'GABA_B')]
# C0c1n124: [('C0c1n118', 'GABA_B'), ('C0c1n119', 'AMPA')]
# C0c1n125: [('C0c1n121', 'AMPA'), ('C0c1n122', 'AMPA')]
# C0c1n126: [('C0c1n123', 'AMPA'), ('C0c1n124', 'AMPA')]
# New configuration applied to DYNAP-SE1!
#
# Number of neurons (using count): 117
# Number of neurons (using net_gen.network): 117
# Number of neurons (using the formula): 117
# Number of synapses (using count): 172
# Number of synapses (using net_gen.network): 172
# Number of synapses (using the formula): 172
# Test with 4: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n12: [('C0c0s1', 'AMPA')]
# C0c1n13: [('C0c1n12', 'AMPA')]
# C0c1n14: [('C0c1n13', 'AMPA')]
# C0c1n15: [('C0c1n14', 'AMPA')]
# C0c1n16: [('C0c1n15', 'AMPA')]
# C0c1n17: [('C0c1n16', 'AMPA')]
# C0c1n18: [('C0c1n17', 'AMPA')]
# C0c1n19: [('C0c1n18', 'AMPA')]
# C0c1n20: [('C0c1n19', 'AMPA')]
# C0c1n21: [('C0c1n20', 'AMPA')]
# C0c1n22: [('C0c1n21', 'AMPA')]
# C0c1n23: [('C0c1n22', 'AMPA')]
# C0c1n24: [('C0c1n23', 'AMPA')]
# C0c1n25: [('C0c1n24', 'AMPA')]
# C0c1n26: [('C0c1n25', 'AMPA')]
# C0c1n27: [('C0c1n26', 'AMPA')]
# C0c1n28: [('C0c1n27', 'AMPA')]
# C0c1n29: [('C0c1n28', 'AMPA')]
# C0c1n30: [('C0c1n29', 'AMPA')]
# C0c1n31: [('C0c1n30', 'AMPA')]
# C0c1n108: [('C0c0s1', 'AMPA'), ('C0c0s2', 'GABA_B')]
# C0c1n109: [('C0c0s1', 'AMPA'), ('C0c0s7', 'GABA_B')]
# C0c1n171: [('C0c1n29', 'AMPA'), ('C0c1n168', 'GABA_B'), ('C0c1n169', 'GABA_B')]
# C0c1n172: [('C0c1n168', 'AMPA'), ('C0c1n169', 'GABA_B')]
# C0c1n173: [('C0c1n168', 'GABA_B'), ('C0c1n169', 'AMPA')]
# C0c1n174: [('C0c1n170', 'AMPA')]
# C0c1n175: [('C0c1n171', 'AMPA')]
# C0c1n176: [('C0c1n30', 'AMPA'), ('C0c1n172', 'GABA_B'), ('C0c1n173', 'GABA_B')]
# C0c1n177: [('C0c1n172', 'AMPA'), ('C0c1n173', 'AMPA')]
# C0c1n178: [('C0c1n174', 'AMPA')]
# C0c1n179: [('C0c1n30', 'AMPA'), ('C0c1n174', 'GABA_B')]
# C0c1n180: [('C0c1n175', 'AMPA')]
# C0c1n181: [('C0c1n31', 'AMPA'), ('C0c1n176', 'GABA_B'), ('C0c1n179', 'GABA_B')]
# C0c1n182: [('C0c1n177', 'AMPA'), ('C0c1n178', 'GABA_B')]
# C0c1n183: [('C0c1n177', 'GABA_B'), ('C0c1n178', 'AMPA')]
# C0c1n184: [('C0c1n180', 'AMPA'), ('C0c1n181', 'AMPA')]
# C0c1n185: [('C0c1n182', 'AMPA'), ('C0c1n183', 'AMPA')]
#
# Number of neurons (using count): 174
# Number of neurons (using net_gen.network): 174
# Number of neurons (using the formula): 174
# Number of synapses (using count): 245
# Number of synapses (using net_gen.network): 245
# Number of synapses (using the formula): 245
# Test with 5: OK!
# New configuration applied to DYNAP-SE1!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n14: [('C0c0s1', 'AMPA')]
# C0c1n15: [('C0c1n14', 'AMPA')]
# C0c1n16: [('C0c1n15', 'AMPA')]
# C0c1n17: [('C0c1n16', 'AMPA')]
# C0c1n18: [('C0c1n17', 'AMPA')]
# C0c1n19: [('C0c1n18', 'AMPA')]
# C0c1n20: [('C0c1n19', 'AMPA')]
# C0c1n21: [('C0c1n20', 'AMPA')]
# C0c1n22: [('C0c1n21', 'AMPA')]
# C0c1n23: [('C0c1n22', 'AMPA')]
# C0c1n24: [('C0c1n23', 'AMPA')]
# C0c1n25: [('C0c1n24', 'AMPA')]
# C0c1n26: [('C0c1n25', 'AMPA')]
# C0c1n27: [('C0c1n26', 'AMPA')]
# C0c1n28: [('C0c1n27', 'AMPA')]
# C0c1n29: [('C0c1n28', 'AMPA')]
# C0c1n30: [('C0c1n29', 'AMPA')]
# C0c1n31: [('C0c1n30', 'AMPA')]
# C0c1n32: [('C0c1n31', 'AMPA')]
# C0c1n33: [('C0c1n32', 'AMPA')]
# C0c1n34: [('C0c1n33', 'AMPA')]
# C0c1n35: [('C0c1n34', 'AMPA')]
# C0c1n36: [('C0c1n35', 'AMPA')]
# C0c1n37: [('C0c1n36', 'AMPA')]
# C0c1n38: [('C0c1n37', 'AMPA')]
# C0c1n159: [('C0c0s1', 'AMPA'), ('C0c0s2', 'GABA_B')]
# C0c1n160: [('C0c0s1', 'AMPA'), ('C0c0s8', 'GABA_B')]
# C0c1n165: [('C0c1n15', 'AMPA'), ('C0c1n40', 'GABA_B')]
# C0c1n166: [('C0c1n15', 'AMPA'), ('C0c1n100', 'GABA_B')]
# C0c1n183: [('C0c1n20', 'AMPA'), ('C0c1n47', 'GABA_B')]
# C0c1n184: [('C0c1n20', 'AMPA'), ('C0c1n107', 'GABA_B')]
# C0c1n201: [('C0c1n25', 'AMPA'), ('C0c1n59', 'GABA_B')]
# C0c1n202: [('C0c1n25', 'AMPA'), ('C0c1n119', 'GABA_B')]
# C0c1n219: [('C0c1n30', 'AMPA'), ('C0c1n76', 'GABA_B')]
# C0c1n220: [('C0c1n30', 'AMPA'), ('C0c1n136', 'GABA_B')]
# C0c1n237: [('C0c1n35', 'AMPA'), ('C0c1n98', 'GABA_B')]
# C0c1n238: [('C0c1n35', 'AMPA'), ('C0c1n158', 'GABA_B')]
# C0c1n39: [('C0c0s3', 'AMPA')]
# C0c1n99: [('C0c0s9', 'AMPA')]
# C0c1n41: [('C0c0s4', 'AMPA')]
# C0c1n101: [('C0c0s10', 'AMPA')]
# C0c1n48: [('C0c0s5', 'AMPA')]
# C0c1n108: [('C0c0s11', 'AMPA')]
# C0c1n60: [('C0c0s6', 'AMPA')]
# C0c1n120: [('C0c0s12', 'AMPA')]
# C0c1n77: [('C0c0s7', 'AMPA')]
# C0c1n137: [('C0c0s13', 'AMPA')]
# C0c1n40: [('C0c1n39', 'AMPA')]
# C0c1n100: [('C0c1n99', 'AMPA')]
# C0c1n42: [('C0c1n41', 'AMPA')]
# C0c1n43: [('C0c1n42', 'AMPA')]
# C0c1n44: [('C0c1n43', 'AMPA')]
# C0c1n45: [('C0c1n44', 'AMPA')]
# C0c1n46: [('C0c1n45', 'AMPA')]
# C0c1n47: [('C0c1n46', 'AMPA')]
# C0c1n102: [('C0c1n101', 'AMPA')]
# C0c1n103: [('C0c1n102', 'AMPA')]
# C0c1n104: [('C0c1n103', 'AMPA')]
# C0c1n105: [('C0c1n104', 'AMPA')]
# C0c1n106: [('C0c1n105', 'AMPA')]
# C0c1n107: [('C0c1n106', 'AMPA')]
# C0c1n49: [('C0c1n48', 'AMPA')]
# C0c1n50: [('C0c1n49', 'AMPA')]
# C0c1n51: [('C0c1n50', 'AMPA')]
# C0c1n52: [('C0c1n51', 'AMPA')]
# C0c1n53: [('C0c1n52', 'AMPA')]
# C0c1n54: [('C0c1n53', 'AMPA')]
# C0c1n55: [('C0c1n54', 'AMPA')]
# C0c1n56: [('C0c1n55', 'AMPA')]
# C0c1n57: [('C0c1n56', 'AMPA')]
# C0c1n58: [('C0c1n57', 'AMPA')]
# C0c1n59: [('C0c1n58', 'AMPA')]
# C0c1n109: [('C0c1n108', 'AMPA')]
# C0c1n110: [('C0c1n109', 'AMPA')]
# C0c1n111: [('C0c1n110', 'AMPA')]
# C0c1n112: [('C0c1n111', 'AMPA')]
# C0c1n113: [('C0c1n112', 'AMPA')]
# C0c1n114: [('C0c1n113', 'AMPA')]
# C0c1n115: [('C0c1n114', 'AMPA')]
# C0c1n188: [('C0c1n183', 'GABA_B'), ('C0c1n184', 'AMPA')]
# C0c1n189: [('C0c1n185', 'AMPA')]
# C0c1n190: [('C0c1n186', 'AMPA')]
# C0c1n191: [('C0c1n22', 'AMPA'), ('C0c1n187', 'GABA_B'), ('C0c1n188', 'GABA_B')]
# C0c1n192: [('C0c1n187', 'AMPA'), ('C0c1n188', 'AMPA')]
# C0c1n193: [('C0c1n189', 'AMPA')]
# C0c1n194: [('C0c1n22', 'AMPA'), ('C0c1n189', 'GABA_B')]
# C0c1n195: [('C0c1n190', 'AMPA')]
# C0c1n196: [('C0c1n23', 'AMPA'), ('C0c1n191', 'GABA_B'), ('C0c1n194', 'GABA_B')]
# C0c1n197: [('C0c1n192', 'AMPA'), ('C0c1n193', 'GABA_B')]
# C0c1n198: [('C0c1n192', 'GABA_B'), ('C0c1n193', 'AMPA')]
# C0c1n199: [('C0c1n195', 'AMPA'), ('C0c1n196', 'AMPA')]
# C0c1n203: [('C0c1n199', 'AMPA')]
# C0c1n200: [('C0c1n197', 'AMPA'), ('C0c1n198', 'AMPA')]
# C0c1n204: [('C0c1n26', 'AMPA'), ('C0c1n201', 'GABA_B'), ('C0c1n202', 'GABA_B')]
# C0c1n205: [('C0c1n201', 'AMPA'), ('C0c1n202', 'GABA_B')]
# C0c1n206: [('C0c1n201', 'GABA_B'), ('C0c1n202', 'AMPA')]
# C0c1n207: [('C0c1n203', 'AMPA')]
# C0c1n208: [('C0c1n204', 'AMPA')]
# C0c1n209: [('C0c1n27', 'AMPA'), ('C0c1n205', 'GABA_B'), ('C0c1n206', 'GABA_B')]
# C0c1n210: [('C0c1n205', 'AMPA'), ('C0c1n206', 'AMPA')]
# C0c1n211: [('C0c1n207', 'AMPA')]
# C0c1n212: [('C0c1n27', 'AMPA'), ('C0c1n207', 'GABA_B')]
# C0c1n213: [('C0c1n208', 'AMPA')]
# C0c1n214: [('C0c1n28', 'AMPA'), ('C0c1n209', 'GABA_B'), ('C0c1n212', 'GABA_B')]
# C0c1n215: [('C0c1n210', 'AMPA'), ('C0c1n211', 'GABA_B')]
# C0c1n216: [('C0c1n210', 'GABA_B'), ('C0c1n211', 'AMPA')]
# C0c1n217: [('C0c1n213', 'AMPA'), ('C0c1n214', 'AMPA')]
# C0c1n221: [('C0c1n217', 'AMPA')]
# C0c1n218: [('C0c1n215', 'AMPA'), ('C0c1n216', 'AMPA')]
# C0c1n222: [('C0c1n31', 'AMPA'), ('C0c1n219', 'GABA_B'), ('C0c1n220', 'GABA_B')]
# C0c1n223: [('C0c1n219', 'AMPA'), ('C0c1n220', 'GABA_B')]
# C0c1n224: [('C0c1n219', 'GABA_B'), ('C0c1n220', 'AMPA')]
# C0c1n225: [('C0c1n221', 'AMPA')]
# C0c1n226: [('C0c1n222', 'AMPA')]
# C0c1n227: [('C0c1n32', 'AMPA'), ('C0c1n223', 'GABA_B'), ('C0c1n224', 'GABA_B')]
# C0c1n228: [('C0c1n223', 'AMPA'), ('C0c1n224', 'AMPA')]
# C0c1n229: [('C0c1n225', 'AMPA')]
# C0c1n230: [('C0c1n32', 'AMPA'), ('C0c1n225', 'GABA_B')]
# C0c1n231: [('C0c1n226', 'AMPA')]
# C0c1n232: [('C0c1n33', 'AMPA'), ('C0c1n227', 'GABA_B'), ('C0c1n230', 'GABA_B')]
# C0c1n233: [('C0c1n228', 'AMPA'), ('C0c1n229', 'GABA_B')]
# C0c1n234: [('C0c1n228', 'GABA_B'), ('C0c1n229', 'AMPA')]
# C0c1n235: [('C0c1n231', 'AMPA'), ('C0c1n232', 'AMPA')]
# C0c1n239: [('C0c1n235', 'AMPA')]
# C0c1n236: [('C0c1n233', 'AMPA'), ('C0c1n234', 'AMPA')]
# C0c1n240: [('C0c1n36', 'AMPA'), ('C0c1n237', 'GABA_B'), ('C0c1n238', 'GABA_B')]
# C0c1n241: [('C0c1n237', 'AMPA'), ('C0c1n238', 'GABA_B')]
# C0c1n242: [('C0c1n237', 'GABA_B'), ('C0c1n238', 'AMPA')]
# C0c1n243: [('C0c1n239', 'AMPA')]
# C0c1n244: [('C0c1n240', 'AMPA')]
# C0c1n245: [('C0c1n37', 'AMPA'), ('C0c1n241', 'GABA_B'), ('C0c1n242', 'GABA_B')]
# C0c1n246: [('C0c1n241', 'AMPA'), ('C0c1n242', 'AMPA')]
# C0c1n247: [('C0c1n243', 'AMPA')]
# C0c1n248: [('C0c1n37', 'AMPA'), ('C0c1n243', 'GABA_B')]
# C0c1n249: [('C0c1n244', 'AMPA')]
# C0c1n250: [('C0c1n38', 'AMPA'), ('C0c1n245', 'GABA_B'), ('C0c1n248', 'GABA_B')]
# C0c1n251: [('C0c1n246', 'AMPA'), ('C0c1n247', 'GABA_B')]
# C0c1n252: [('C0c1n246', 'GABA_B'), ('C0c1n247', 'AMPA')]
# C0c1n253: [('C0c1n249', 'AMPA'), ('C0c1n250', 'AMPA')]
# C0c1n254: [('C0c1n251', 'AMPA'), ('C0c1n252', 'AMPA')]
# New configuration applied to DYNAP-SE1!
#
# Number of neurons (using count): 241
# Number of neurons (using net_gen.network): 241
# Number of neurons (using the formula): 241
# Number of synapses (using count): 328
# Number of synapses (using net_gen.network): 328
# Number of synapses (using the formula): 328
# Test with 6: OK!

# %%
def build_decoder(n_bits, debug):
    # silent all neurons: enforces some biases to ensure neurons are NOT firing
    paramGroup = params.gen_clean_param_group()
    for chip in range(4):
        for core in range(4):
            model.update_parameter_group(paramGroup, chip, core)

    api  = model.get_dynapse1_api()

    # ---- Parameters ----
    n_delay = 1

    # ---- Spike generator ----
    spike_generator_ids = range(1, n_bits + 1)
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    id_ini = 1
    id_end = id_ini + n_bits * 2
    input_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += n_bits * 2 + 1
    middle_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 2 ** n_bits - 1
    output_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0
        
    # Input layer
    for i in range(n_bits): # 2 * n
        net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * i + 1], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2
            
        for j in range(i + 1, n_bits):  # (n - 1) * (1 + (n - 1)) / 2 = (n ^ 2 - n) / 2
            net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * j + 1], dyn1.Dynapse1SynType.GABA_B)
            total_synapses += 1

    # Middle layer
    for i in range(n_bits): # 2 * n
        net_gen.add_connection(input_layer.neurons[2 * i], middle_layer.neurons[2 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(input_layer.neurons[2 * i], middle_layer.neurons[2 * i + 1], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2
    
        # OP to NOT -> n ^ 2
        for j in range(n_bits):   
            net_gen.add_connection(input_layer.neurons[2 * i + 1], middle_layer.neurons[2 * j + 1], dyn1.Dynapse1SynType.AMPA)
            total_synapses += 1
    
        # OP (+1) -> n
        net_gen.add_connection(input_layer.neurons[2 * i + 1], middle_layer.neurons[-1], dyn1.Dynapse1SynType.AMPA)  
        total_synapses += 1

    # Output layer 
    for i in range(1, 2 ** n_bits): # 2 ^ n - 1
        i_bin = format(i, "0" + str(n_bits) + "b").reversed()

        # Inhibition
        for j in range(len(i_bin)):  
            if i_bin[j] == '1':
                net_gen.add_connection(middle_layer.neurons[2 * j + 1], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.GABA_B)  
            else:
                net_gen.add_connection(middle_layer.neurons[2 * j], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.GABA_B) 
            total_synapses += 1
    
        # Excitation (OP (+1)) 
        net_gen.add_connection(middle_layer.neurons[-1], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.AMPA)  
        total_synapses += 1

    # make a dynapse1config using the network: that is convert the validated network to a Dynapse1 configuration
    new_config = net_gen.make_dynapse1_configuration()

    # apply the configuration
    model.apply_configuration(new_config)

    # Print resources
    neurons_count = id_end - 1
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = 2 ** n_bits + 4 * n_bits

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = (n_bits + 1) * 2 ** n_bits + 2 * n_bits ** 2 + 3 * n_bits - 1

    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_bits) + ": OK!")
    else:
        print("Test with " + str(n_bits) + ": FAILED!")

# %%
for i in range(1, 8):
    build_decoder(i, 0)
# Out:
# New configuration applied to DYNAP-SE1!
# Test with 1: OK!
# Test with 2: OK!
# New configuration applied to DYNAP-SE1!
# Test with 3: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 4: OK!
# Test with 5: OK!New configuration applied to DYNAP-SE1!
#
# Test with 6: OK!New configuration applied to DYNAP-SE1!
#
# New configuration applied to DYNAP-SE1!
# Test with 7: OK!

# %%
def build_decoder_no_DynapSE(n_bits, debug):
    # ---- Spike generator ----
    spike_generator_ids = range(1, n_bits + 1)
    spike_generators = n.NeuronGroup(0, 0, spike_generator_ids, True)  # Avoid spike generator with ID 0

    # ---- DPI Neurons ----
    id_ini = 1
    id_end = id_ini + n_bits * 2
    input_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += n_bits * 2 + 1
    middle_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    id_ini = id_end
    id_end += 2 ** n_bits - 1
    output_layer = n.NeuronGroup(0, 1, range(id_ini, id_end), False)

    # ---- Synapses ----
    net_gen = n.NetworkGenerator()
    total_synapses = 0
        
    # Input layer
    for i in range(n_bits): # 2 * n
        net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * i + 1], dyn1.Dynapse1SynType.AMPA)
        total_synapses += 2
            
        for j in range(i + 1, n_bits):  # (n - 1) * (1 + (n - 1)) / 2 = (n ^ 2 - n) / 2
            net_gen.add_connection(spike_generators.neurons[i], input_layer.neurons[2 * j + 1], dyn1.Dynapse1SynType.GABA_B)
            total_synapses += 1

    # Middle layer
    for i in range(n_bits): # 2 * n
        net_gen.add_connection(input_layer.neurons[2 * i], middle_layer.neurons[2 * i], dyn1.Dynapse1SynType.AMPA)
        net_gen.add_connection(input_layer.neurons[2 * i], middle_layer.neurons[2 * i + 1], dyn1.Dynapse1SynType.GABA_B)
        total_synapses += 2
    
        # OP to NOT -> n ^ 2
        for j in range(n_bits):   
            net_gen.add_connection(input_layer.neurons[2 * i + 1], middle_layer.neurons[2 * j + 1], dyn1.Dynapse1SynType.AMPA)
            total_synapses += 1
    
        # OP (+1) -> n
        net_gen.add_connection(input_layer.neurons[2 * i + 1], middle_layer.neurons[-1], dyn1.Dynapse1SynType.AMPA)  
        total_synapses += 1

    # Output layer 
    for i in range(1, 2 ** n_bits): # 2 ^ n - 1
        i_bin = format(i, "0" + str(n_bits) + "b")[::-1]

        # Inhibition
        for j in range(len(i_bin)):  
            if i_bin[j] == '1':
                net_gen.add_connection(middle_layer.neurons[2 * j + 1], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.GABA_B)  
            else:
                net_gen.add_connection(middle_layer.neurons[2 * j], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.GABA_B) 
            total_synapses += 1
    
        # Excitation (OP (+1)) 
        net_gen.add_connection(middle_layer.neurons[-1], output_layer.neurons[i - 1], dyn1.Dynapse1SynType.AMPA)  
        total_synapses += 1

    # Print resources
    neurons_count = id_end - 1
    neurons_network = len(str(net_gen.network).splitlines()) - 1
    neurons_formula = 2 ** n_bits + 4 * n_bits

    synapses_count = total_synapses
    synapses_network = str(net_gen.network).count("('")
    synapses_formula = (n_bits + 1) * 2 ** n_bits + 3 / 2 * n_bits ** 2 + 7 / 2 * n_bits - 1 


    if debug:
        print(net_gen.network)

        print("Number of neurons (using count): " + str(neurons_count))
        print("Number of neurons (using net_gen.network): " + str(neurons_network))
        print("Number of neurons (using the formula): " + str(neurons_formula))

        print("Number of synapses (using count): " + str(synapses_count))
        print("Number of synapses (using net_gen.network): " + str(synapses_network))
        print("Number of synapses (using the formula): " + str(synapses_formula))

    if neurons_count == neurons_network and neurons_network == neurons_formula and synapses_count == synapses_network and synapses_network == synapses_formula:
        print("Test with " + str(n_bits) + ": OK!")
    else:
        print("Test with " + str(n_bits) + ": FAILED!")

# %%
for i in range(1, 8):
    build_decoder_no_DynapSE(i, 1)
# Out:
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n3: [('C0c1n1', 'AMPA')]
# C0c1n4: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA')]
# C0c1n5: [('C0c1n2', 'AMPA')]
# C0c1n6: [('C0c1n4', 'GABA_B'), ('C0c1n5', 'AMPA')]
#
# Number of neurons (using count): 6
# Number of neurons (using net_gen.network): 6
# Number of neurons (using the formula): 6
# Number of synapses (using count): 8
# Number of synapses (using net_gen.network): 8
# Number of synapses (using the formula): 8.0
# Test with 1: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c1n1', 'AMPA')]
# C0c1n6: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA')]
# C0c1n8: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA')]
# C0c1n9: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA')]
# C0c1n7: [('C0c1n3', 'AMPA')]
# C0c1n10: [('C0c1n6', 'GABA_B'), ('C0c1n7', 'GABA_B'), ('C0c1n9', 'AMPA')]
# C0c1n11: [('C0c1n5', 'GABA_B'), ('C0c1n8', 'GABA_B'), ('C0c1n9', 'AMPA')]
# C0c1n12: [('C0c1n6', 'GABA_B'), ('C0c1n8', 'GABA_B'), ('C0c1n9', 'AMPA')]
#
# Number of neurons (using count): 12
# Number of neurons (using net_gen.network): 12
# Number of neurons (using the formula): 12
# Number of synapses (using count): 24
# Number of synapses (using net_gen.network): 24
# Number of synapses (using the formula): 24.0
# Test with 2: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n6: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c0s3', 'AMPA')]
# C0c1n7: [('C0c1n1', 'AMPA')]
# C0c1n8: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA')]
# C0c1n10: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA')]
# C0c1n12: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n5', 'GABA_B'), ('C0c1n6', 'AMPA')]
# C0c1n13: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA')]
# C0c1n9: [('C0c1n3', 'AMPA')]
# C0c1n11: [('C0c1n5', 'AMPA')]
# C0c1n14: [('C0c1n8', 'GABA_B'), ('C0c1n9', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n15: [('C0c1n7', 'GABA_B'), ('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n16: [('C0c1n8', 'GABA_B'), ('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n17: [('C0c1n7', 'GABA_B'), ('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n18: [('C0c1n8', 'GABA_B'), ('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n19: [('C0c1n7', 'GABA_B'), ('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'AMPA')]
# C0c1n20: [('C0c1n8', 'GABA_B'), ('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'AMPA')]
#
# Number of neurons (using count): 20
# Number of neurons (using net_gen.network): 20
# Number of neurons (using the formula): 20
# Number of synapses (using count): 55
# Number of synapses (using net_gen.network): 55
# Number of synapses (using the formula): 55.0
# Test with 3: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n6: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'AMPA')]
# C0c1n8: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c0s3', 'AMPA')]
# C0c1n7: [('C0c0s4', 'AMPA')]
# C0c1n9: [('C0c1n1', 'AMPA')]
# C0c1n10: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA')]
# C0c1n12: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA')]
# C0c1n14: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n5', 'GABA_B'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA')]
# C0c1n16: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n7', 'GABA_B'), ('C0c1n8', 'AMPA')]
# C0c1n17: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA')]
# C0c1n11: [('C0c1n3', 'AMPA')]
# C0c1n13: [('C0c1n5', 'AMPA')]
# C0c1n15: [('C0c1n7', 'AMPA')]
# C0c1n18: [('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n19: [('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n20: [('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n21: [('C0c1n9', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n22: [('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n23: [('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n24: [('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n25: [('C0c1n9', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n26: [('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n27: [('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n28: [('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n29: [('C0c1n9', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n30: [('C0c1n10', 'GABA_B'), ('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n31: [('C0c1n9', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
# C0c1n32: [('C0c1n10', 'GABA_B'), ('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'AMPA')]
#
# Number of neurons (using count): 32
# Number of neurons (using net_gen.network): 32
# Number of neurons (using the formula): 32
# Number of synapses (using count): 117
# Number of synapses (using net_gen.network): 117
# Number of synapses (using the formula): 117.0
# Test with 4: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n6: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'AMPA')]
# C0c1n8: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'AMPA')]
# C0c1n10: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c0s3', 'AMPA')]
# C0c1n7: [('C0c0s4', 'AMPA')]
# C0c1n9: [('C0c0s5', 'AMPA')]
# C0c1n11: [('C0c1n1', 'AMPA')]
# C0c1n12: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA')]
# C0c1n14: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA')]
# C0c1n16: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n5', 'GABA_B'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA')]
# C0c1n18: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n7', 'GABA_B'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA')]
# C0c1n20: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n9', 'GABA_B'), ('C0c1n10', 'AMPA')]
# C0c1n21: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA')]
# C0c1n13: [('C0c1n3', 'AMPA')]
# C0c1n15: [('C0c1n5', 'AMPA')]
# C0c1n17: [('C0c1n7', 'AMPA')]
# C0c1n19: [('C0c1n9', 'AMPA')]
# C0c1n22: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n23: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n24: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n25: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n26: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n27: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n28: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n29: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n30: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n31: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n32: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n33: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n34: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n35: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n36: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n37: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n38: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n39: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n40: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n41: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n42: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n43: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n44: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n45: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n46: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n47: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n48: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n49: [('C0c1n11', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n50: [('C0c1n12', 'GABA_B'), ('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n51: [('C0c1n11', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
# C0c1n52: [('C0c1n12', 'GABA_B'), ('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'AMPA')]
#
# Number of neurons (using count): 52
# Number of neurons (using net_gen.network): 52
# Number of neurons (using the formula): 52
# Number of synapses (using count): 246
# Number of synapses (using net_gen.network): 246
# Number of synapses (using the formula): 246.0
# Test with 5: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n6: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'AMPA')]
# C0c1n8: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'AMPA')]
# C0c1n10: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'AMPA')]
# C0c1n12: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'GABA_B'), ('C0c0s6', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c0s3', 'AMPA')]
# C0c1n7: [('C0c0s4', 'AMPA')]
# C0c1n9: [('C0c0s5', 'AMPA')]
# C0c1n11: [('C0c0s6', 'AMPA')]
# C0c1n13: [('C0c1n1', 'AMPA')]
# C0c1n14: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n16: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n18: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n5', 'GABA_B'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n20: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n7', 'GABA_B'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n22: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n9', 'GABA_B'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n24: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n11', 'GABA_B'), ('C0c1n12', 'AMPA')]
# C0c1n25: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA')]
# C0c1n15: [('C0c1n3', 'AMPA')]
# C0c1n17: [('C0c1n5', 'AMPA')]
# C0c1n19: [('C0c1n7', 'AMPA')]
# C0c1n21: [('C0c1n9', 'AMPA')]
# C0c1n23: [('C0c1n11', 'AMPA')]
# C0c1n26: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n27: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n28: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n29: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n30: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n31: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n32: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n33: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n34: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n35: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n36: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n37: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n38: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n39: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n40: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n41: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n42: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n43: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n44: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n45: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n46: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n47: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n48: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n49: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n50: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n51: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n52: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n53: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n54: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n55: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n56: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n57: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n58: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n59: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n60: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n61: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n62: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n63: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n64: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n65: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n66: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n67: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n68: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n69: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n70: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n71: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n72: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n73: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n74: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n75: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n76: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n77: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n78: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n79: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n80: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n81: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n82: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n83: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n84: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n85: [('C0c1n13', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n86: [('C0c1n14', 'GABA_B'), ('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n87: [('C0c1n13', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
# C0c1n88: [('C0c1n14', 'GABA_B'), ('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'AMPA')]
#
# Number of neurons (using count): 88
# Number of neurons (using net_gen.network): 88
# Number of neurons (using the formula): 88
# Number of synapses (using count): 522
# Number of synapses (using net_gen.network): 522
# Number of synapses (using the formula): 522.0
# Test with 6: OK!
# Post neuron (ChipId,coreId,neuronId): incoming connections [(preNeuron,synapseType), ...]
# C0c1n1: [('C0c0s1', 'AMPA')]
# C0c1n2: [('C0c0s1', 'AMPA')]
# C0c1n4: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'AMPA')]
# C0c1n6: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'AMPA')]
# C0c1n8: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'AMPA')]
# C0c1n10: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'AMPA')]
# C0c1n12: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'GABA_B'), ('C0c0s6', 'AMPA')]
# C0c1n14: [('C0c0s1', 'GABA_B'), ('C0c0s2', 'GABA_B'), ('C0c0s3', 'GABA_B'), ('C0c0s4', 'GABA_B'), ('C0c0s5', 'GABA_B'), ('C0c0s6', 'GABA_B'), ('C0c0s7', 'AMPA')]
# C0c1n3: [('C0c0s2', 'AMPA')]
# C0c1n5: [('C0c0s3', 'AMPA')]
# C0c1n7: [('C0c0s4', 'AMPA')]
# C0c1n9: [('C0c0s5', 'AMPA')]
# C0c1n11: [('C0c0s6', 'AMPA')]
# C0c1n13: [('C0c0s7', 'AMPA')]
# C0c1n15: [('C0c1n1', 'AMPA')]
# C0c1n16: [('C0c1n1', 'GABA_B'), ('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n18: [('C0c1n2', 'AMPA'), ('C0c1n3', 'GABA_B'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n20: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n5', 'GABA_B'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n22: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n7', 'GABA_B'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n24: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n9', 'GABA_B'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n26: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n11', 'GABA_B'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n28: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n13', 'GABA_B'), ('C0c1n14', 'AMPA')]
# C0c1n29: [('C0c1n2', 'AMPA'), ('C0c1n4', 'AMPA'), ('C0c1n6', 'AMPA'), ('C0c1n8', 'AMPA'), ('C0c1n10', 'AMPA'), ('C0c1n12', 'AMPA'), ('C0c1n14', 'AMPA')]
# C0c1n17: [('C0c1n3', 'AMPA')]
# C0c1n19: [('C0c1n5', 'AMPA')]
# C0c1n21: [('C0c1n7', 'AMPA')]
# C0c1n23: [('C0c1n9', 'AMPA')]
# C0c1n25: [('C0c1n11', 'AMPA')]
# C0c1n27: [('C0c1n13', 'AMPA')]
# C0c1n30: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n31: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n32: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n33: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n34: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n35: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n36: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n37: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n38: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n39: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n40: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n41: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n42: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n43: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n44: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n45: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n46: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n47: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n48: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n49: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n50: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n51: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n52: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n53: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n54: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n55: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n56: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n57: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n58: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n59: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n60: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n61: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n62: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n63: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n64: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n65: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n66: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n67: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n68: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n69: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n70: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n71: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n72: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n73: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n74: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n75: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n76: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n77: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n78: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n79: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n80: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n81: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n82: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n83: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n84: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n85: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n86: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n87: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n88: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n89: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n90: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n91: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n92: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n27', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n93: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n94: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n95: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n96: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n97: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n98: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n99: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n100: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n101: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n102: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n103: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n104: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n105: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n106: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n107: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n108: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n109: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n110: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n111: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n112: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n113: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n114: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n115: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n116: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n117: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n118: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n119: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n120: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n121: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n122: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n123: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n124: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n25', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n125: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n126: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n127: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n128: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n129: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n130: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n131: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n132: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n133: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n134: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n135: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n136: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n137: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n138: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n139: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n140: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n23', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n141: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n142: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n143: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n144: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n145: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n146: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n147: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n148: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n21', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n149: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n150: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n151: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n152: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n19', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n153: [('C0c1n15', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n154: [('C0c1n16', 'GABA_B'), ('C0c1n17', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n155: [('C0c1n15', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
# C0c1n156: [('C0c1n16', 'GABA_B'), ('C0c1n18', 'GABA_B'), ('C0c1n20', 'GABA_B'), ('C0c1n22', 'GABA_B'), ('C0c1n24', 'GABA_B'), ('C0c1n26', 'GABA_B'), ('C0c1n28', 'GABA_B'), ('C0c1n29', 'AMPA')]
#
# Number of neurons (using count): 156
# Number of neurons (using net_gen.network): 156
# Number of neurons (using the formula): 156
# Number of synapses (using count): 1121
# Number of synapses (using net_gen.network): 1121
# Number of synapses (using the formula): 1121.0
# Test with 7: OK!

# %% [markdown]
# ## Close the device

# %%
# remeber to close the device
samna.device.close_device(model)
